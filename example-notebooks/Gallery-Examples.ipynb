# %%
%m3md
# Mathics3 Gallery Examples

Here, we have some examples of running Mathics3 in a Jupyter notebook.

## Examples involving calculations
# Out:
# # Mathics3 Gallery Examples
#
# Here, we have some examples of running Mathics3 in a Jupyter notebook.
#
# ## Examples involving calculations

# %%
Sin[Pi]
# Out:
# <div style="text-align: left; overflow-x: auto;"><math >
#  <mn>0</mn>
# </math></div>

# %%
(* Calculate Euler's famous equation: *)
E^(Pi I)
# Out:
# <div style="text-align: left; overflow-x: auto;"><math >
#  <mrow>
#   <mn>-</mn>
#   <mn>1</mn>
#  </mrow>
# </math></div>

# %%
(* An example using Factorial. Arbitrary-length integers are supported: *)
30!
# Out:
# <div style="text-align: left; overflow-x: auto;"><math >
#  <mn>265252859812191058636308480000000</mn>
# </math></div>

# %%
(* A 30-digit numeric approximation of Euler's E: *)
N[E, 30]
(* N[] converts a large integer to a MachineReal without loss of precision. *)
# Out:
# <div style="text-align: left; overflow-x: auto;"><math >
#  <mn>2.718281828459045235360287471353</mn>
# </math></div>

# %%
(* The first n=8, odd numbers (n+1)**2: *)
n = 8; 2 ^ # & /@ Range[0, n]
# Out:
# <div style="text-align: left; overflow-x: auto;"><math >
#  <mrow>
#   <mo>{</mo>
#   <mrow>
#    <mn>1</mn>
#    <mo>,</mo>
#    <mn>2</mn>
#    <mo>,</mo>
#    <mn>4</mn>
#    <mo>,</mo>
#    <mn>8</mn>
#    <mo>,</mo>
#    <mn>16</mn>
#    <mo>,</mo>
#    <mn>32</mn>
#    <mo>,</mo>
#    <mn>64</mn>
#    <mo>,</mo>
#    <mn>128</mn>
#    <mo>,</mo>
#    <mn>256</mn>
#   </mrow>
#   <mo>}</mo>
#  </mrow>
# </math></div>
